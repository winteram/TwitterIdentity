# %%
import sys, os
import pandas as pd
import cPickle as pickle
import re
import numpy as np
# %matplotlib 

os.chdir('C:/Users/Asaf/Documents/GitHub/TwitterIdentity/src/py')



from vaderSentiment import sentiment as vaderSentiment

survey=pd.read_pickle('DataFrames/SurveySentiment')

# %%
survey['fear']
# Out:
# 0     10
# 1      9
# 2      5
# 3    NaN
# 4      5
# 5     16
# 6      5
# 7      9
# 8      8
# 9      5
# 10     6
# 11    10
# 12    10
# 13     6
# 14     7
# ...
# 800    14
# 801    10
# 802   NaN
# 803     8
# 804     8
# 805     9
# 806     7
# 807     9
# 808    15
# 809   NaN
# 810     9
# 811     4
# 812     6
# 813     9
# 814    10
# Name: fear, Length: 815, dtype: float64

# %%
y=['active','distressed','interested']



names={'fear':['afraid','scared', 'nervous','jittery'],
       'hostility_1':['hostile','irritable','upset'] , 
       'hostilitity':['hostile','irritable'], 
       'guilt':['ashamed','guilty'], 
       'fatigue':['tired'], 
       'joviality':['excited', 'enthusiastic'],
       'joviality_1':['excited', 'enthusiastic', 'inspired'], 
       'self_assurance':['proud','strong'], 
       'attentiveness':['alert', 'attentive',  'determined']}

for factor in names.keys():
    survey[factor]=0
    for i in names[factor]:
        survey[factor]+=survey[i]
        
        
        
    


#sadness=[]

# %%
pickle.dump(survey,open('DataFrames/SurveySentiment', 'wb'))

# %%
survey['fear']
# Out:
# 0     10
# 1      9
# 2      5
# 3    NaN
# 4      5
# 5     16
# 6      5
# 7      9
# 8      8
# 9      5
# 10     6
# 11    10
# 12    10
# 13     6
# 14     7
# ...
# 800    14
# 801    10
# 802   NaN
# 803     8
# 804     8
# 805     9
# 806     7
# 807     9
# 808    15
# 809   NaN
# 810     9
# 811     4
# 812     6
# 813     9
# 814    10
# Name: fear, Length: 815, dtype: float64

# %%
k=list(survey.keys())

# %%
k
# Out:
# ['Agree',
#  'FBid',
#  'IUname',
#  'Id',
#  'Referred_by',
#  'Twitid',
#  'active',
#  'afraid',
#  'alert',
#  'ashamed',
#  'attentive',
#  'comments',
#  'con_agree_0',
#  'con_agree_1',
#  'con_agree_10',
#  'con_agree_11',
#  'con_agree_12',
#  'con_agree_13',
#  'con_agree_14',
#  'con_agree_15',
#  'con_agree_16',
#  'con_agree_17',
#  'con_agree_18',
#  'con_agree_19',
#  'con_agree_2',
#  'con_agree_20',
#  'con_agree_21',
#  'con_agree_22',
#  'con_agree_23',
#  'con_agree_24',
#  'con_agree_25',
#  'con_agree_26',
#  'con_agree_27',
#  'con_agree_28',
#  'con_agree_29',
#  'con_agree_3',
#  'con_agree_30',
#  'con_agree_31',
#  'con_agree_32',
#  'con_agree_33',
#  'con_agree_34',
#  'con_agree_4',
#  'con_agree_5',
#  'con_agree_6',
#  'con_agree_7',
#  'con_agree_8',
#  'con_agree_9',
#  'determined',
#  'distressed',
#  'edu',
#  'ended',
#  'enthusiastic',
#  'ethnicity',
#  'excited',
#  'fam_income',
#  'fb_academic',
#  'fb_academic_comments',
# ...
